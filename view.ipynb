# %%
import glob
import pandas as pd

# %%
train_raw = None

for p in glob.glob('train/*.csv'):
    data = pd.read_csv(p)
    if train_raw is None:
        train_raw = data
        continue
    train_raw = pd.concat([train_raw, data])

# %%
train_raw
# Out:
#                   timestamp     C01  C02       C03      C04        C05  \
# 0       2021-08-06 09:00:01 -1.9192    0  12.24670 -0.00094  100.73242
# 1       2021-08-06 09:00:02 -2.7392    0  12.24670  0.00065  100.73242
# 2       2021-08-06 09:00:03 -2.5925    0  12.25433 -0.00217  100.73242
# 3       2021-08-06 09:00:04 -2.5925    0  12.23907  0.00130  100.73242
# 4       2021-08-06 09:00:05 -2.5495    0  12.24670 -0.00145  100.74005
# ...                     ...     ...  ...       ...      ...        ...
# 201595  2021-07-19 07:59:56 -0.9169    0  12.09412 -0.00058   12.30774
# 201596  2021-07-19 07:59:57 -0.9169    0  12.09412 -0.00058   12.26959
# 201597  2021-07-19 07:59:58 -0.6298    0  12.09412 -0.00051   12.60528
# 201598  2021-07-19 07:59:59 -0.4378    0  12.09412  0.00275   14.46686
# 201599  2021-07-19 08:00:00 -0.2859    0  12.09412  0.00441   14.46686
#
#            C06       C07  C08  C09  ...      C77       C78      C79  \
# ...
